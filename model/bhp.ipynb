# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Bengaluru_House_Data.csv")

# %%
df.head(10)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5  Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6  Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7  Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8  Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9            Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df.shape
# Out:
# (13320, 9)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.groupby('area_type')['area_type'].agg('count')
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
df2=df.drop(['area_type','availability','society','balcony'],axis="columns")
df2.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0   51.00

# %%
df2['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', nan, '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df2.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df2.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0   51.00

# %%
df3=df2.dropna()
df3.head()
df3.shape
# Out:
# (13246, 5)

# %%
df3['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df3['BHK']=df3['size'].apply(lambda x:int(x.split(' ')[0]))
# Out:
# C:\Users\praka\AppData\Local\Temp\ipykernel_1588\329588128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['BHK']=df3['size'].apply(lambda x:int(x.split(' ')[0]))

# %%
df3['BHK'].unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18], dtype=int64)

# %%
df3=df3.drop('size',axis='columns')
df3.head()
# Out:
#                    location total_sqft  bath   price  BHK
# 0  Electronic City Phase II       1056   2.0   39.07    2
# 1          Chikka Tirupathi       2600   5.0  120.00    4
# 2               Uttarahalli       1440   2.0   62.00    3
# 3        Lingadheeranahalli       1521   3.0   95.00    3
# 4                  Kothanur       1200   2.0   51.00    2

# %%
df3['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def convert_sqft_to_num(x):
    token=x.split('-')
    if len(token)==2:
        return (float(token[0])+float(token[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
convert_sqft_to_num('35')
# Out:
# 35.0

# %%
convert_sqft_to_num('35-45')
# Out:
# 40.0

# %%
df4=df3.copy()
df4['total_sqft']=df4['total_sqft'].apply(convert_sqft_to_num)
df4.head(10)
# Out:
#                    location  total_sqft  bath   price  BHK
# 0  Electronic City Phase II      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi      2600.0   5.0  120.00    4
# 2               Uttarahalli      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      1521.0   3.0   95.00    3
# 4                  Kothanur      1200.0   2.0   51.00    2
# 5                Whitefield      1170.0   2.0   38.00    2
# 6          Old Airport Road      2732.0   4.0  204.00    4
# 7              Rajaji Nagar      3300.0   4.0  600.00    4
# 8              Marathahalli      1310.0   3.0   63.25    3
# 9              Gandhi Bazar      1020.0   6.0  370.00    6

# %%
df4['price_per_sqft']=df4['price']*100000/df4['total_sqft']
df5=df4.copy()
len(df5.location.unique())
# Out:
# 1304

# %%
df5['location']=df5.location.apply(lambda x: x.strip())
loc=df5.location.unique()
loc
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
loc=df5.groupby('location')['location'].agg('count')
loc
# Out:
# location
# 1 Annasandrapalya                                  1
# 1 Giri Nagar                                       1
# 1 Immadihalli                                      1
# 1 Ramamurthy Nagar                                 1
# 12th cross srinivas nagar banshankari 3rd stage    1
#                                                   ..
# t.c palya                                          1
# tc.palya                                           4
# vinayakanagar                                      1
# white field,kadugodi                               1
# whitefiled                                         1
# Name: location, Length: 1293, dtype: int64

# %%
loc=df5.groupby('location')['location'].agg('count').sort_values(ascending=False)
loc
# Out:
# location
# Whitefield               535
# Sarjapur  Road           392
# Electronic City          304
# Kanakpura Road           266
# Thanisandra              236
#                         ...
# 1 Giri Nagar               1
# Kanakapura Road,           1
# Kanakapura main  Road      1
# Karnataka Shabarimala      1
# whitefiled                 1
# Name: location, Length: 1293, dtype: int64

# %%
loc_other=loc[loc<=10]
loc_other
# Out:
# location
# Basapura                 10
# 1st Block Koramangala    10
# Gunjur Palya             10
# Kalkere                  10
# Sector 1 HSR Layout      10
#                          ..
# 1 Giri Nagar              1
# Kanakapura Road,          1
# Kanakapura main  Road     1
# Karnataka Shabarimala     1
# whitefiled                1
# Name: location, Length: 1052, dtype: int64

# %%
def others_loc(x):
    if x in loc_other:
        return 'others'
    else:
        return x

# %%
df5.location=df5.location.apply(others_loc)
df5.head(20)
# Out:
#                     location  total_sqft  bath   price  BHK  price_per_sqft
# 0   Electronic City Phase II      1056.0   2.0   39.07    2     3699.810606
# 1           Chikka Tirupathi      2600.0   5.0  120.00    4     4615.384615
# 2                Uttarahalli      1440.0   2.0   62.00    3     4305.555556
# 3         Lingadheeranahalli      1521.0   3.0   95.00    3     6245.890861
# 4                   Kothanur      1200.0   2.0   51.00    2     4250.000000
# 5                 Whitefield      1170.0   2.0   38.00    2     3247.863248
# 6           Old Airport Road      2732.0   4.0  204.00    4     7467.057101
# 7               Rajaji Nagar      3300.0   4.0  600.00    4    18181.818182
# 8               Marathahalli      1310.0   3.0   63.25    3     4828.244275
# 9                     others      1020.0   6.0  370.00    6    36274.509804
# 10                Whitefield      1800.0   2.0   70.00    3     3888.888889
# ...

# %%
len(df5.location.unique())
# Out:
# 242

# %%
df6=df5[~(df5.total_sqft/df5.BHK<300)]
df6
# Out:
#                        location  total_sqft  bath   price  BHK  price_per_sqft
# 0      Electronic City Phase II      1056.0   2.0   39.07    2     3699.810606
# 1              Chikka Tirupathi      2600.0   5.0  120.00    4     4615.384615
# 2                   Uttarahalli      1440.0   2.0   62.00    3     4305.555556
# 3            Lingadheeranahalli      1521.0   3.0   95.00    3     6245.890861
# 4                      Kothanur      1200.0   2.0   51.00    2     4250.000000
# ...                         ...         ...   ...     ...  ...             ...
# 13315                Whitefield      3453.0   4.0  231.00    5     6689.834926
# 13316                    others      3600.0   5.0  400.00    4    11111.111111
# 13317     Raja Rajeshwari Nagar      1141.0   2.0   60.00    2     5258.545136
# 13318           Padmanabhanagar      4689.0   4.0  488.00    4    10407.336319
# 13319              Doddathoguru       550.0   1.0   17.00    1     3090.909091
#
# ...

# %%
df6.price_per_sqft.describe()
# Out:
# count     12456.000000
# mean       6308.502826
# std        4168.127339
# min         267.829813
# 25%        4210.526316
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
df6.shape
# Out:
# (12502, 6)

# %%
def remove_pps_outliers(df):
    df_out=pd.DataFrame()
    for key, subdf in df.groupby('location'):
        m=np.mean(subdf.price_per_sqft)
        st=np.std(subdf.price_per_sqft)
        reduced_df=subdf[(subdf.price_per_sqft>(m-st)) & (subdf.price_per_sqft<=(m+st))]
        df_out=pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out

# %%
df7=remove_pps_outliers(df6)
df7.shape
# Out:
# (10241, 6)

# %%
df7
# Out:
#                   location  total_sqft  bath   price  BHK  price_per_sqft
# 0      1st Block Jayanagar      2850.0   4.0  428.00    4    15017.543860
# 1      1st Block Jayanagar      1630.0   3.0  194.00    3    11901.840491
# 2      1st Block Jayanagar      1875.0   2.0  235.00    3    12533.333333
# 3      1st Block Jayanagar      1200.0   2.0  130.00    3    10833.333333
# 4      1st Block Jayanagar      1235.0   2.0  148.00    2    11983.805668
# ...                    ...         ...   ...     ...  ...             ...
# 10236               others      1353.0   2.0  110.00    2     8130.081301
# 10237               others       812.0   1.0   26.00    1     3201.970443
# 10238               others      1440.0   2.0   63.93    3     4439.583333
# 10239               others      1075.0   2.0   48.00    2     4465.116279
# 10240               others      3600.0   5.0  400.00    4    11111.111111
#
# [10241 rows x 6 columns]

# %%
def scatterplt(df,location):
    b2=df[(df.location==location) &  (df.BHK==2)]
    b3=df[(df.location==location) &  (df.BHK==3)]
    plt.scatter(b2.total_sqft,b2.price_per_sqft , marker='*' , color='red',label='2 BHK' ,s=50)
    plt.scatter(b3.total_sqft,b3.price_per_sqft , marker='+' ,color='blue', label='3 BHK' ,s=50)
    plt.xlabel('Total_sqft')
    plt.ylabel('Price')
    plt.legend()

scatterplt(df7,"Rajaji Nagar")

# %%
scatterplt(df7,"Hebbal")

# %%
def remove_bhk_outliers(df):
    exclude_indices=np.array([])
    for location , location_df in df.groupby('location'):
        bhk_stats={}
        for bhk , bhk_df in location_df.groupby('BHK'):
            bhk_stats[bhk]={
                'mean': np.mean(bhk_df.price_per_sqft),
                'st': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
                }
        for bhk , bhk_df in location_df.groupby('BHK'):
            stats=bhk_stats.get(bhk)
            if stats['count']>3:
                exclude_indices=np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean']-(1.5*stats['st']))].index.values)
                exclude_indices=np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft>(stats['mean']+(1.5*stats['st']))].index.values)
    return df.drop(exclude_indices, axis='index')

df8=remove_bhk_outliers(df7)
df8
# Out:
#                   location  total_sqft  bath   price  BHK  price_per_sqft
# 0      1st Block Jayanagar      2850.0   4.0  428.00    4    15017.543860
# 1      1st Block Jayanagar      1630.0   3.0  194.00    3    11901.840491
# 2      1st Block Jayanagar      1875.0   2.0  235.00    3    12533.333333
# 3      1st Block Jayanagar      1200.0   2.0  130.00    3    10833.333333
# 4      1st Block Jayanagar      1235.0   2.0  148.00    2    11983.805668
# ...                    ...         ...   ...     ...  ...             ...
# 10236               others      1353.0   2.0  110.00    2     8130.081301
# 10237               others       812.0   1.0   26.00    1     3201.970443
# 10238               others      1440.0   2.0   63.93    3     4439.583333
# 10239               others      1075.0   2.0   48.00    2     4465.116279
# 10240               others      3600.0   5.0  400.00    4    11111.111111
#
# [9104 rows x 6 columns]

# %%
scatterplt(df8,"Rajaji Nagar")

# %%
scatterplt(df8,"Hebbal")

# %%
df8[df8.bath>(df8.BHK+2)]
# Out:
#            location  total_sqft  bath   price  BHK  price_per_sqft
# 1626  Chikkabanavar      2460.0   7.0    80.0    4     3252.032520
# 5238     Nagasandra      7000.0   8.0   450.0    4     6428.571429
# 6711    Thanisandra      1806.0   6.0   116.0    3     6423.034330
# 8411         others     11338.0   9.0  1000.0    6     8819.897689

# %%
df9=df8[df8.bath<(df8.BHK+2)]
df9
# Out:
#                   location  total_sqft  bath   price  BHK  price_per_sqft
# 0      1st Block Jayanagar      2850.0   4.0  428.00    4    15017.543860
# 1      1st Block Jayanagar      1630.0   3.0  194.00    3    11901.840491
# 2      1st Block Jayanagar      1875.0   2.0  235.00    3    12533.333333
# 3      1st Block Jayanagar      1200.0   2.0  130.00    3    10833.333333
# 4      1st Block Jayanagar      1235.0   2.0  148.00    2    11983.805668
# ...                    ...         ...   ...     ...  ...             ...
# 10236               others      1353.0   2.0  110.00    2     8130.081301
# 10237               others       812.0   1.0   26.00    1     3201.970443
# 10238               others      1440.0   2.0   63.93    3     4439.583333
# 10239               others      1075.0   2.0   48.00    2     4465.116279
# 10240               others      3600.0   5.0  400.00    4    11111.111111
#
# [9020 rows x 6 columns]

# %%
df10=df9.drop(['price_per_sqft'], axis='columns')
df10.head(3)
# Out:
#               location  total_sqft  bath  price  BHK
# 0  1st Block Jayanagar      2850.0   4.0  428.0    4
# 1  1st Block Jayanagar      1630.0   3.0  194.0    3
# 2  1st Block Jayanagar      1875.0   2.0  235.0    3

# %%
dummies=pd.get_dummies(df10.location)
dummies
# Out:
#        1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                     True               False                      False
# 1                     True               False                      False
# 2                     True               False                      False
# 3                     True               False                      False
# 4                     True               False                      False
# ...                    ...                 ...                        ...
# 10236                False               False                      False
# 10237                False               False                      False
# 10238                False               False                      False
# 10239                False               False                      False
# 10240                False               False                      False
#
#        2nd Stage Nagarbhavi  5th Block Hbr Layout  5th Phase JP Nagar  \
# ...

# %%
df11=pd.concat([df10.drop(['location'],axis='columns'), dummies.drop(['others'], axis='columns')],axis='columns')
df11.head(3)
# Out:
#    total_sqft  bath  price  BHK  1st Block Jayanagar  1st Phase JP Nagar  \
# 0      2850.0   4.0  428.0    4                 True               False
# 1      1630.0   3.0  194.0    3                 True               False
# 2      1875.0   2.0  235.0    3                 True               False
#
#    2nd Phase Judicial Layout  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# 0                      False                 False                 False
# 1                      False                 False                 False
# 2                      False                 False                 False
#
#    5th Phase JP Nagar  ...  Vijayanagar  Vishveshwarya Layout  \
# 0               False  ...        False                 False
# 1               False  ...        False                 False
# 2               False  ...        False                 False
#
#    Vishwapriya Layout  Vittasandra  Whitefield  Yelachenahalli  Yelahanka  \
# ...

# %%
x=df11.drop(['price'],axis='columns')
x.head(2)
# Out:
#    total_sqft  bath  BHK  1st Block Jayanagar  1st Phase JP Nagar  \
# 0      2850.0   4.0    4                 True               False
# 1      1630.0   3.0    3                 True               False
#
#    2nd Phase Judicial Layout  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# 0                      False                 False                 False
# 1                      False                 False                 False
#
#    5th Phase JP Nagar  6th Phase JP Nagar  ...  Vijayanagar  \
# 0               False               False  ...        False
# 1               False               False  ...        False
#
#    Vishveshwarya Layout  Vishwapriya Layout  Vittasandra  Whitefield  \
# 0                 False               False        False       False
# 1                 False               False        False       False
#
#    Yelachenahalli  Yelahanka  Yelahanka New Town  Yelenahalli  Yeshwanthpur
# ...

# %%
y=df11.price
y.head(2)
# Out:
# 0    428.0
# 1    194.0
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split, ShuffleSplit, cross_val_score

# %%
x_train , x_test, y_train, y_test= train_test_split(x, y, test_size=0.2, random_state=10)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train, y_train)
model.score(x_test, y_test)
# Out:
# 0.7901826442953561

# %%
cvs=ShuffleSplit(n_splits=4, test_size=0.2, random_state=0)
cross_val_score(LinearRegression(), x, y, cv=cvs)
# Out:
# array([0.87420023, 0.85201287, 0.82851766, 0.82644066])

# %%
x.columns
# Out:
# Index(['total_sqft', 'bath', 'BHK', '1st Block Jayanagar',
#        '1st Phase JP Nagar', '2nd Phase Judicial Layout',
#        '2nd Stage Nagarbhavi', '5th Block Hbr Layout', '5th Phase JP Nagar',
#        '6th Phase JP Nagar',
#        ...
#        'Vijayanagar', 'Vishveshwarya Layout', 'Vishwapriya Layout',
#        'Vittasandra', 'Whitefield', 'Yelachenahalli', 'Yelahanka',
#        'Yelahanka New Town', 'Yelenahalli', 'Yeshwanthpur'],
#       dtype='object', length=244)

# %%
def predict_price(location, sqft, bath, bhk):
    loc_index=np.where(x.columns==location)[0][0]
    a=np.zeros(len(x.columns))
    a[0]=sqft
    a[1]=bath
    a[2]=bhk
    if loc_index>=0:
        a[loc_index]=1
    
    return model.predict([a])[0]

# %%
predict_price("Rajaji Nagar", 2500, 2, 2)
# Out:
# C:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 334.02987427650356

# %%
import pickle
with open('bhp.pickle', 'wb') as f:
    pickle.dump(model, f)

# %%
import json
with open('columns.json', 'w') as f:
    columns={
        'data_columns':[col.lower() for col in x.columns]
    }
    f.write(json.dumps(columns))
